# %% [markdown]
# # Matplotlib

# %% [markdown]
# Importar modulo de matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Preguntar si esta en modo interactivo

# %%
plt.isinteractive()
# Out:
# True

# %% [markdown]
# Para cambiar entre modos

# %%
plt.ioff()

# %%
plt.isinteractive()
# Out:
# False

# %%
plt.ion()
plt.isinteractive()
# Out:
# True

# %%
plt.plot([1,2,3,4,5,6])
plt.show()

# %%
import numpy as np

# %%
x = np.linspace (0,10,100)

# %%
plt.plot(np.exp(x))

# %%
plt.plot(np.sin(x))

# %%
plt.plot(x,np.sin(x))
plt.show()

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.show()

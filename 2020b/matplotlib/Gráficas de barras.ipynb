# %% [markdown]
# ## Gráficas de barras

# %% [markdown]
# ## Ejemplo 1

# %%
# Importamos modulos
import matplotlib.pyplot as plt
import numpy as np 

# Definir Datos
x1 = range(10)

y1 = np.random.randint(0, 100, 10)
y2 = np.random.randint(0, 100, 10)

#Definir características del gráfico
plt.bar (x1, y1, label='Datos 1', color='lightblue' )
plt.bar (x1, y2, label='Datos 2', color='orange')

#Definir titulo y nombre de ejes
plt.title('Gráfico de barras')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')

#Mostrar leyenda y gráfico
plt.legend()
plt.show()

# %% [markdown]
# Lista de colores
# https://matplotlib.org/3.1.0/gallery/color/named_colors.html

# %% [markdown]
# ## Ejemplo 2

# %%
# Importamos modulos
import matplotlib.pyplot as plt
import numpy as np 

# Definir Datos
x1 = np.arange(10)
y1 = np.random.randint(0, 100, 10)
x2 = x1 + .4
y2 = np.random.randint(0, 100, 10)

#Definir características del gráfico
plt.bar (x1, y1, label='Datos 1', color='lightblue', width=0.4)
plt.bar (x2, y2, label='Datos 2', color='orange', width=0.4)

#Definir titulo y nombre de ejes
plt.title('Gráfico de barras')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')

#Mostrar leyenda y gráfico
plt.legend()
plt.show()

# %% [markdown]
# ## Ejemplo 3

# %%
# Importamos modulos
import matplotlib.pyplot as plt
import numpy as np 

# Definir Datos
x1 = np.arange(10)
y1 = np.random.randint(0, 100, 10)
x2 = x1 + .4
y2 = np.random.randint(0, 100, 10)

#Definir características del gráfico
plt.barh (x1, y1, label='Datos 1', color='lightblue')
plt.barh (x2, y2, label='Datos 2', color='orange')

#Definir titulo y nombre de ejes
plt.title('Gráfico de barras')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')

#Mostrar leyenda y gráfico
plt.legend()
plt.show()

# %% [markdown]
# ## Ejemplo 4

# %%
# Importamos modulos
import matplotlib.pyplot as plt
import numpy as np 

# Definir Datos
x1 = np.arange(10)
y1 = np.random.randint(0, 100, 10)
x2 = x1 + .4
y2 = np.random.randint(0, 100, 10)

#Definir características del gráfico
plt.barh (x1, y1, label='Datos 1', color='lightblue', height=.4)
plt.barh (x2, y2, label='Datos 2', color='orange', height=.4)

#Definir titulo y nombre de ejes
plt.title('Gráfico de barras')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')

#Mostrar leyenda y gráfico
plt.legend()
plt.show()

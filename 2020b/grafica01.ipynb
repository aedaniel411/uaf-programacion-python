# %%
# %matplotlib notebook

# %% [markdown]
# importar modulos
#
#     numpy
#
#     pandas
#
#     optimaze
#
#     matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Definir los datos
#
# datos para x
#
# datos para y
#
# en ocasiones datos z

# %%
x = np.linspace (-2*np.pi, 2*np.pi)
y = np.sin(x)

# %% [markdown]
# definir grafica

# %%
plt.figure(10)
plt.plot(x,y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7833333333333">

# %%
y = np.exp(x)

# %%
plt.figure(15)
plt.plot(x,y)
plt.show()

# %%
plt.plot (x, np.sin(x))
plt.plot(x,np.cos(x))

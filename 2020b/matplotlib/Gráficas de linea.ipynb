# %% [markdown]
# ## Gráficas de linea

# %%
import matplotlib.pyplot as plt
import numpy as np

#Definimos datos
t = np.arange(0., 5., 0.2)
#t = np.linspace(0., 5., 25)

#Definimos gráfica
plt.plot(t, t)
plt.plot(t, t**2) 
plt.plot(t, t**3)

#Mostramos gráfica
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#Definimos datos
#t = np.arange(0., 5., 0.2)
t = np.linspace(0., 5., 25)

#Definimos gráfica
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')

#Mostramos gráfica
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

nums = np.arange(0,10,0.1)

plt.plot(nums, np.sin(nums), label='1')
plt.plot(1+nums, np.sin(nums), label='2')
plt.plot(2+nums, np.sin(nums), label='3')
plt.plot(3+nums, np.sin(nums), label='4')
plt.plot(4+nums, np.sin(nums), label='5')

#plt.legend(loc='best')
#plt.legend(loc=10)
plt.legend(loc='center right')
plt.show()

# %% [markdown]
# 0. 'best' (only implemented for axes' legends)
# 1. 'upper right'
# 2. 'upper left'
# 3. 'lower left'
# 4. 'lower right'
# 5. 'right' (igual a 'center right'; por retro-compatibilidad)
# 6. 'center left'
# 7. 'center right'
# 8. 'lower center'
# 9. 'upper center'
# 10. 'center'
